# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# PREGUNTA 4
#
# a)

# %%
ds_data = pd.read_csv(os.path.join("Data","AFP_returns.csv"))

# %%
ds_data.head()
# Out:
#       Date  Capital.A  Capital.B  Capital.C  Capital.D  Capital.E  Cuprum.A  \
# 0  2005-08        NaN        NaN        NaN        NaN        NaN     -0.62
# 1  2005-09        NaN        NaN        NaN        NaN        NaN      3.03
# 2  2005-10        NaN        NaN        NaN        NaN        NaN     -4.17
# 3  2005-11        NaN        NaN        NaN        NaN        NaN      2.11
# 4  2005-12        NaN        NaN        NaN        NaN        NaN      1.64
#
#    Cuprum.B  Cuprum.C  Cuprum.D  ...  ProVida.A  ProVida.B  ProVida.C  \
# 0     -0.56     -0.31      0.05  ...      -0.60      -0.39      -0.26
# 1      2.10      1.32      0.60  ...       3.44       2.14       1.23
# 2     -3.58     -3.09     -3.00  ...      -4.49      -3.91      -3.38
# 3      0.80     -0.14     -0.68  ...       2.50       0.77      -0.24
# 4      0.91      0.61      0.51  ...       1.85       0.83       0.63
#
#    ProVida.D  ProVida.E  system.A  system.B  system.C  system.D  system.E
# 0       0.14       0.77     -0.67     -0.47     -0.31      0.07      0.75
# 1       0.39      -0.55      3.21      2.17      1.22      0.49     -0.51
# 2      -2.92      -2.75     -4.28     -3.72     -3.21     -2.85     -2.81
# 3      -0.53      -0.79      2.23      0.84     -0.22     -0.54     -0.87
# 4       0.39       0.74      1.65      0.89      0.61      0.49      0.81
#
# [5 rows x 36 columns]

# %%
fondo = "A"
t = np.arange(177)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(20, 10), sharex=True, sharey=True)

ax1.plot(t, ds_data["Habitat."+fondo], "b")
ax1.grid()
ax1.set_title("Habitat."+fondo)

ax2.plot(t, ds_data["Cuprum."+fondo], "r")
ax2.grid()
ax2.set_title("Cuprum."+fondo)

ax3.plot(t, ds_data["ProVida."+fondo], "g")
ax3.grid()
ax3.set_title("ProVida."+fondo)

ax4.plot(t, ds_data["PlanVital."+fondo], "m")
ax4.grid()
ax4.set_title("PlanVital."+fondo)

fig.show()
# Out:
# /Users/IkeMercado/miniconda3/envs/mat281/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# b) Chamullo

# %%
ds_data[["Habitat."+fondo,"Cuprum."+fondo,"ProVida."+fondo,"PlanVital."+fondo]].head()
# Out:
#    Habitat.A  Cuprum.A  ProVida.A  PlanVital.A
# 0      -0.84     -0.62      -0.60        -0.79
# 1       3.26      3.03       3.44         3.15
# 2      -4.16     -4.17      -4.49        -4.34
# 3       2.15      2.11       2.50         2.08
# 4       1.34      1.64       1.85         1.49

# %%
from statsmodels.tsa.api import VAR

# %%
#auxi = ds_data[["Habitat.A","Cuprum.A","ProVida.A","PlanVital.A"]]
#del auxi.index.name

# %%
auxi = VAR(ds_data[["Habitat."+fondo,"Cuprum."+fondo,"ProVida."+fondo,"PlanVital."+fondo]])

# %%
M = 15
auxi.select_order(M).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
